# %%
from pyspark.sql import SparkSession
import os 
import pandas as pd

# This forces Pandas to show every single row and column
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)

os.environ['HADOOP_USER_NAME'] = 'root'

spark = SparkSession.builder \
    .appName("bronze-spark-upload-hdfs") \
    .config("spark.driver.host", "spark-notebook") \
    .config("spark.driver.bindAddress", "0.0.0.0") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
df_listings = spark.sql('SELECT * FROM airbnb_bronze.listings')

# %%
df_listings.show(3)
# Out:
# +-----+--------------------+--------------+------------+-----------+--------------------+--------------------+---------------------+--------------------+-------+--------------------+---------+----------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+--------------------+--------------------+------------------+-------------------+-------------------------+--------------------+--------------------+----------------------+--------------------+----------------------+----------------------------+--------+---------+--------------------+---------------+------------+---------+--------------+--------+----+--------------------+-------+--------------+--------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------+----------------+---------------+---------------+---------------+----------------+---------------------+-----------------+---------------------+----------------------+----------------+--------------------+-------------------------+-----------------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+-------+----------------+------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-----------------+---------------+------+
# |   id|         listing_url|     scrape_id|last_scraped|     source|                name|         description|neighborhood_overview|         picture_url|host_id|            host_url|host_name|host_since|       host_location|          host_about|host_response_time|host_response_rate|host_acceptance_rate|host_is_superhost|  host_thumbnail_url|    host_picture_url|host_neighbourhood|host_listings_count|host_total_listings_count|  host_verifications|host_has_profile_pic|host_identity_verified|       neighbourhood|neighbourhood_cleansed|neighbourhood_group_cleansed|latitude|longitude|       property_type|      room_type|accommodates|bathrooms|bathrooms_text|bedrooms|beds|           amenities|  price|minimum_nights|maximum_nights|minimum_minimum_nights|maximum_minimum_nights|minimum_maximum_nights|maximum_maximum_nights|minimum_nights_avg_ntm|maximum_nights_avg_ntm|calendar_updated|has_availability|availability_30|availability_60|availability_90|availability_365|calendar_last_scraped|number_of_reviews|number_of_reviews_ltm|number_of_reviews_l30d|availability_eoy|number_of_reviews_ly|estimated_occupancy_l365d|estimated_revenue_l365d|first_review|last_review|review_scores_rating|review_scores_accuracy|review_scores_cleanliness|review_scores_checkin|review_scores_communication|review_scores_location|review_scores_value|license|instant_bookable|calculated_host_listings_count|calculated_host_listings_count_entire_homes|calculated_host_listings_count_private_rooms|calculated_host_listings_count_shared_rooms|reviews_per_month|extraction_date|  city|
# +-----+--------------------+--------------+------------+-----------+--------------------+--------------------+---------------------+--------------------+-------+--------------------+---------+----------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+--------------------+--------------------+------------------+-------------------+-------------------------+--------------------+--------------------+----------------------+--------------------+----------------------+----------------------------+--------+---------+--------------------+---------------+------------+---------+--------------+--------+----+--------------------+-------+--------------+--------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------+----------------+---------------+---------------+---------------+----------------+---------------------+-----------------+---------------------+----------------------+----------------+--------------------+-------------------------+-----------------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+-------+----------------+------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-----------------+---------------+------+
# |13913|https://www.airbn...|20250914034649|  2025-09-16|city scrape|Holiday London DB...|My bright double ...| Finsbury Park is ...|https://a0.muscac...|  54730|https://www.airbn...|    Alina|2009-11-16|London, United Ki...|I am a Multi-Medi...|within a few hours|              100%|                 96%|                t|https://a0.muscac...|https://a0.muscac...|   LB of Islington|                2.0|                      5.0|  ['email', 'phone']|                   t|                     t|Neighborhood high...|             Islington|                        NULL|51.56861|  -0.1127|Private room in r...|   Private room|           1|      1.0| 1 shared bath|     1.0| 1.0|["Self check-in",...| $70.00|             1|            29|                   1.0|                   1.0|                  29.0|                  29.0|                   1.0|                  29.0|            NULL|               t|             21|             39|             69|             331|           2025-09-16|               55|                   10|                     1|              74|                   8|                       92|                 6440.0|  2010-08-18| 2025-08-21|                4.85|                   4.8|                      4.8|                 4.81|                       4.87|                  4.78|               4.78|    nan|               f|                             2|                                          1|                                           1|                                          0|              0.3|     2025-09-14|london|
# |15400|https://www.airbn...|20250914034649|  2025-09-16|city scrape|Bright Chelsea  A...|Lots of windows a...|       It is Chelsea.|https://a0.muscac...|  60302|https://www.airbn...| Philippa|2009-12-05|Royal Borough of ...|English, grandmot...|              NULL|              NULL|                 50%|                f|https://a0.muscac...|https://a0.muscac...|           Chelsea|                1.0|                      1.0|  ['email', 'phone']|                   t|                     t|Neighborhood high...|  Kensington and Ch...|                        NULL| 51.4878| -0.16813|  Entire rental unit|Entire home/apt|           2|      1.0|        1 bath|     1.0| 1.0|["Kitchen", "Smok...|$149.00|             4|            30|                   4.0|                   4.0|                  30.0|                  30.0|                   4.0|                  30.0|            NULL|               t|              0|              0|              0|             199|           2025-09-16|               97|                    1|                     0|               0|                   2|                        9|                 1341.0|  2009-12-21| 2025-04-05|                 4.8|                  4.86|                     4.87|                 4.88|                       4.84|                  4.93|               4.74|    nan|               f|                             1|                                          1|                                           0|                                          0|             0.51|     2025-09-14|london|
# |17402|https://www.airbn...|20250914034649|  2025-09-16|city scrape|Very Central Mode...|You'll have a gre...| Fitzrovia is a ve...|https://a0.muscac...|  67564|https://www.airbn...|      Liz|2010-01-04|London, United Ki...|We are Liz and Ja...|    within an hour|               88%|                 88%|                t|https://a0.muscac...|https://a0.muscac...|         Fitzrovia|                3.0|                     16.0|['email', 'phone'...|                   t|                     t|Neighborhood high...|           Westminster|                        NULL|51.52195| -0.14094|  Entire rental unit|Entire home/apt|           6|      2.0|       2 baths|     3.0| 3.0|["Kitchen", "Clea...|$411.00|             3|           365|                   3.0|                   3.0|                 365.0|                 365.0|                   3.0|                 365.0|            NULL|               t|             24|             54|             64|              80|           2025-09-16|               56|                    0|                     0|              78|                   1|                        0|                    0.0|  2011-03-21| 2024-02-19|                4.77|                  4.83|                     4.72|                 4.72|                       4.72|                  4.89|               4.61|    nan|               f|                             2|                                          2|                                           0|                                          0|             0.32|     2025-09-14|london|
# +-----+--------------------+--------------+------------+-----------+--------------------+--------------------+---------------------+--------------------+-------+--------------------+---------+----------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+--------------------+--------------------+------------------+-------------------+-------------------------+--------------------+--------------------+----------------------+--------------------+----------------------+----------------------------+--------+---------+--------------------+---------------+------------+---------+--------------+--------+----+--------------------+-------+--------------+--------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------+----------------+---------------+---------------+---------------+----------------+---------------------+-----------------+---------------------+----------------------+----------------+--------------------+-------------------------+-----------------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+-------+----------------+------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-----------------+---------------+------+
# only showing top 3 rows

# %%
# Remove url and metadata columns (such as scraping related information)
df_listings = df_listings.drop('listing_url','host_url','picture_url','scrape_id','last_scraped', 'host_thumbnail_url','host_picture_url')

# %%
# View one row vertically (great for inspection)
df_listings.describe().show(n=1, vertical=True)

# Convert to Pandas for a beautiful interactive table (if in a Notebook)
df_listings.describe().toPandas().transpose()
# Out:
# -RECORD 0----------------------------------------------
#  summary                                      | count
#  id                                           | 104652
#  source                                       | 104652
#  name                                         | 104652
#  description                                  | 102106
#  neighborhood_overview                        | 45376
#  host_id                                      | 104652
#  host_name                                    | 104607
#  host_since                                   | 104609
#  host_location                                | 79379
#  host_about                                   | 54337
#  host_response_time                           | 72217
#  host_response_rate                           | 72217
#  host_acceptance_rate                         | 76371
#  host_is_superhost                            | 102708
#  host_neighbourhood                           | 47482
#  host_listings_count                          | 104609
#  host_total_listings_count                    | 104609
#  host_verifications                           | 104609
#  host_has_profile_pic                         | 104609
#  host_identity_verified                       | 104609
#  neighbourhood                                | 45377
#  neighbourhood_cleansed                       | 104652
#  neighbourhood_group_cleansed                 | 0
#  latitude                                     | 104652
#  longitude                                    | 104652
#  property_type                                | 104652
#  room_type                                    | 104652
#  accommodates                                 | 104652
#  bathrooms                                    | 69161
#  bathrooms_text                               | 104491
#  bedrooms                                     | 91678
#  beds                                         | 69072
#  amenities                                    | 104652
#  price                                        | 69093
#  minimum_nights                               | 104652
#  maximum_nights                               | 104652
#  minimum_minimum_nights                       | 104636
#  maximum_minimum_nights                       | 104636
#  minimum_maximum_nights                       | 104636
#  maximum_maximum_nights                       | 104636
#  minimum_nights_avg_ntm                       | 104652
#  maximum_nights_avg_ntm                       | 104652
#  calendar_updated                             | 0
#  has_availability                             | 100362
#  availability_30                              | 104652
#  availability_60                              | 104652
#  availability_90                              | 104652
#  availability_365                             | 104652
#  calendar_last_scraped                        | 104652
#  number_of_reviews                            | 104652
#  number_of_reviews_ltm                        | 104652
#  number_of_reviews_l30d                       | 104652
#  availability_eoy                             | 104652
#  number_of_reviews_ly                         | 104652
#  estimated_occupancy_l365d                    | 104652
#  estimated_revenue_l365d                      | 69093
#  first_review                                 | 79922
#  last_review                                  | 79922
#  review_scores_rating                         | 79922
#  review_scores_accuracy                       | 79907
#  review_scores_cleanliness                    | 79913
#  review_scores_checkin                        | 79879
#  review_scores_communication                  | 79902
#  review_scores_location                       | 79878
#  review_scores_value                          | 79878
#  license                                      | 104652
#  instant_bookable                             | 104652
#  calculated_host_listings_count               | 104652
#  calculated_host_listings_count_entire_homes  | 104652
#  calculated_host_listings_count_private_rooms | 104652
#  calculated_host_listings_count_shared_rooms  | 104652
#  reviews_per_month                            | 79922
#  city                                         | 104652
# only showing top 1 row
#                                                    0                      1                      2                                                  3                                                  4
# summary                                        count                   mean                 stddev                                                min                                                max
# id                                            104652   6.880464475250432E17  5.9346916406908659E17                                              13913                                1518113294243873256
# source                                        104652                   None                   None                                        city scrape                                    previous scrape
# name                                          104652                 1956.5      3887.701677512478         ! ! ! Single studio ! ! ! in Golders Green                🤴 Kingsize room with balcony and TV
# description                                   102106      2.203735331717E12  3.1165523939921245E12          Nestled in heart of Islington and only...  🪴 Welcome to our Little Garden Annexe 🪴 <br />...
# neighborhood_overview                          45376  1.111111111111111E123                    0.0  ""Perfect Location for all the christmas festi...  🥂Coal Drops Yard <br />🚂 Kings Cross station <...
# host_id                                       104652   2.1320979415888852E8   2.1858496306885305E8                                               2381                                          718690455
# host_name                                     104607                    NaN                    NaN                                            'Connor                                                 현주
# host_since                                    104609                   None                   None                                         2008-08-21                                         2025-09-12
# host_location                                  79379                   None                   None                                    A Coruña, Spain                                Šiauliai, Lithuania
# host_about                                     54337               738117.0                   None                                                 \n  안녕하세요. 영국 뉴몰든에 위치한 원룸입니다. 새로 지어서 아주 깨끗하고 런던 여행...
# host_response_time                             72217                   None                   None                                 a few days or more                                     within an hour
# host_response_rate                             72217                   None                   None                                                 0%                                                99%
# host_acceptance_rate                           76371                   None                   None                                                 0%                                                99%
# host_is_superhost                             102708                   None                   None                                                  f                                                  t
# host_neighbourhood                             47482                   None                   None                                         Abbey Wood                                                 火炭
# host_listings_count                           104609     47.936114483457445      384.9829300578964                                                1.0                                             5469.0
# host_total_listings_count                     104609      78.02100201703486      573.3018345581579                                                1.0                                             8774.0
# host_verifications                            104609                   None                   None                 ['email', 'phone', 'photographer']                                                 []
# host_has_profile_pic                          104609                   None                   None                                                  f                                                  t
# host_identity_verified                        104609                   None                   None                                                  f                                                  t
# neighbourhood                                  45377                   None                   None                            Neighborhood highlights                            Neighborhood highlights
# neighbourhood_cleansed                        104652                   None                   None                                          Abbeyhill                                      Windmill Hill
# neighbourhood_group_cleansed                       0                   None                   None                                               None                                               None
# latitude                                      104652       51.7178466966443     0.9428314130365285                                          51.295937                                           55.99195
# longitude                                     104652    -0.3394553192430462       0.75800577813958                                           -3.44254                                            0.27896
# property_type                                 104652                   None                   None                                               Barn                                               Yurt
# room_type                                     104652                   None                   None                                    Entire home/apt                                        Shared room
# accommodates                                  104652     3.3436723617322173     2.0896283666856754                                                  1                                                 16
# bathrooms                                      69161      1.349539480342968     0.7178758170660827                                                0.0                                               26.0
# bathrooms_text                                104491                   None                   None                                            0 baths                                   Shared half-bath
# bedrooms                                       91678     1.6145858330242806     1.0559971736210274                                                0.0                                               50.0
# beds                                           69072     1.9711894834375725     1.4859238146914853                                                0.0                                               50.0
# amenities                                     104652                   None                   None  [" Gilchrist and Soames conditioner", "Safe", ...                                                 []
# price                                          69093                   None                   None                                          $1,000.00                                            $999.00
# minimum_nights                                104652      5.281628635859802      23.10151611093283                                                  1                                               1125
# maximum_nights                                104652      5641.489488972977     1622961.2137343588                                                  1                                          524855552
# minimum_minimum_nights                        104636      4.686876409648687     21.247472887647014                                                1.0                                             1125.0
# maximum_minimum_nights                        104636      8.762672502771514     32.511408901515246                                                1.0                                             1125.0
# minimum_maximum_nights                        104636      5729.662955388203     1623085.0234439184                                                1.0                                       5.24855552E8
# maximum_maximum_nights                        104636      272561.4231048587   2.3990050502977666E7                                                1.0                                      2.147483647E9
# minimum_nights_avg_ntm                        104652     6.0847150556128735      22.80181679992825                                                1.0                                             1125.0
# maximum_nights_avg_ntm                        104652      270429.4739450746    2.380209087638796E7                                                1.0                                     2.1357166195E9
# calendar_updated                                   0                   None                   None                                               None                                               None
# has_availability                              100362                   None                   None                                                  t                                                  t
# availability_30                               104652      9.379304743339832      10.93513644139459                                                  0                                                 30
# availability_60                               104652      22.40718763138784     22.946620990225966                                                  0                                                 60
# availability_90                               104652      36.52297137178458      35.43934959283997                                                  0                                                 90
# availability_365                              104652     146.63145472613996       140.880073201122                                                  0                                                365
# calendar_last_scraped                         104652                   None                   None                                         2025-09-14                                         2025-09-26
# number_of_reviews                             104652     26.865344188357604      64.30206975379072                                                  0                                               1902
# number_of_reviews_ltm                         104652      6.834814432595651     13.943701905901591                                                  0                                                390
# number_of_reviews_l30d                        104652     0.6114646638382448     1.4567064629116144                                                  0                                                 67
# availability_eoy                              104652      43.65456943011122      41.68127229544006                                                  0                                                109
# number_of_reviews_ly                          104652      5.713029851316745     13.550555158451683                                                  0                                                272
# estimated_occupancy_l365d                     104652      50.39587394411956      78.36702572480473                                                  0                                                255
# estimated_revenue_l365d                        69093     11665.446774637083      69339.29679012434                                                0.0                                            1.015E7
# first_review                                   79922                   None                   None                                         2009-12-21                                         2025-09-23
# last_review                                    79922                   None                   None                                         2011-07-02                                         2025-09-26
# review_scores_rating                           79922      4.692423112534781     0.4824558797240046                                                0.0                                                5.0
# review_scores_accuracy                         79907      4.733375549075893    0.46792448142378523                                                0.0                                                5.0
# review_scores_cleanliness                      79913      4.660188955489106     0.5041593459863747                                                0.0                                                5.0
# review_scores_checkin                          79879      4.795509583244738     0.4191543877455446                                                0.0                                                5.0
# review_scores_communication                    79902      4.816713974618992     0.4155120424949234                                                0.0                                                5.0
# review_scores_location                         79878      4.735485740754669    0.39940317380082085                                                0.0                                                5.0
# review_scores_value                            79878      4.620793835599347      0.500125569355519                                                0.0                                                5.0
# license                                       104652                    NaN                    NaN                                        07734317350                                                nan
# instant_bookable                              104652                   None                   None                                                  f                                                  t
# calculated_host_listings_count                104652     16.201047280510643       51.6053096800025                                                  1                                                500
# calculated_host_listings_count_entire_homes   104652       13.9091942820013      50.92743481197441                                                  0                                                499
# calculated_host_listings_count_private_rooms  104652       2.22975193976226      9.294659088151544                                                  0                                                116
# calculated_host_listings_count_shared_rooms   104652   0.028169552421358407     0.6170888249491706                                                  0                                                 25
# reviews_per_month                              79922      1.111695152773978     1.4602309235800932                                               0.01                                              48.55
# city                                          104652                   None                   None                                            bristol                                             london

# %%
# Remove columns with only NULL values

df_listings = df_listings.drop('calendar_updated','neighbourhood_group_cleansed')

# Check distinct values of neighbourhood (only NULL or Neighbourhood highlights)
df_listings.select('neighbourhood').distinct().show()
df_listings = df_listings.drop('neighbourhood')

# Remove columns that does not hold meaningful//analyzable values

df_listings = df_listings.drop('name','description','neighborhood_overview','host_about','license','bathrooms_text','source')
# Out:
# +--------------------+
# |       neighbourhood|
# +--------------------+
# |Neighborhood high...|
# |                NULL|
# +--------------------+

# %%
# some columns has data types that can be formatted

# 1) host_since: string -> datetime
# 2) host_response_time: string -> datetime
# 3） host_response_rate: string -> float
# 4) host_acceptance_rate: string -> float
# 5) price: string -> float
# 6) first_review: string -> datetime
# 7) last_review: string -> datetime

from pyspark.sql.functions import to_timestamp, col, regexp_replace, coalesce, lit, size

datetime_cols = ['host_since','first_review','last_review']
for c in datetime_cols:
    df_listings = df_listings.withColumn(
        c,
        to_timestamp(c, 'yyyy-MM-dd')
    )

df_listings = df_listings.withColumn(
    'price',
    regexp_replace(col('price'), "[$, ]", "").cast("float")
)

for c in ['host_response_rate','host_acceptance_rate']:
    df_listings = df_listings.withColumn(
        c,
        coalesce(
             regexp_replace(c, "%", "").cast("float") / 100,
            lit(0.0)
        )
    )

# Remove rows where Price is NULL

df_listings = df_listings.filter(
    col('price').isNotNull()
)

# %%
hdfs_destination = "hdfs://namenode:9000/user/hive/warehouse/airbnb.db/silver/listings"

(df_listings.write
    .mode("overwrite") \
    .partitionBy("extraction_date", "city") \
    .format("parquet") \
    .save(hdfs_destination))

print(f"✅ Ingestion complete. Data stored at: {hdfs_destination}")
# Out:
# ✅ Ingestion complete. Data stored at: hdfs://namenode:9000/user/hive/warehouse/airbnb.db/silver/listings

# %%
# 1. Create the Database
spark.sql("CREATE DATABASE IF NOT EXISTS airbnb_silver")

# 2. Create the Table
spark.sql('''
CREATE EXTERNAL TABLE IF NOT EXISTS airbnb_silver.stg_listings (
    id BIGINT,

    host_id BIGINT,
    host_name STRING,
    host_since TIMESTAMP,
    host_location STRING,
    host_response_time STRING,
    host_response_rate DOUBLE,
    host_acceptance_rate DOUBLE,
    host_is_superhost STRING,
    host_neighbourhood STRING,
    host_listings_count DOUBLE,
    host_total_listings_count DOUBLE,
    host_verifications STRING,
    host_has_profile_pic STRING,
    host_identity_verified STRING,

    neighbourhood_cleansed STRING,
    latitude DOUBLE,
    longitude DOUBLE,

    property_type STRING,
    room_type STRING,
    accommodates BIGINT,
    bathrooms DOUBLE,
    bedrooms DOUBLE,
    beds DOUBLE,
    amenities STRING,

    price FLOAT,

    minimum_nights BIGINT,
    maximum_nights BIGINT,
    minimum_minimum_nights DOUBLE,
    maximum_minimum_nights DOUBLE,
    minimum_maximum_nights DOUBLE,
    maximum_maximum_nights DOUBLE,
    minimum_nights_avg_ntm DOUBLE,
    maximum_nights_avg_ntm DOUBLE,

    has_availability STRING,
    availability_30 BIGINT,
    availability_60 BIGINT,
    availability_90 BIGINT,
    availability_365 BIGINT,

    calendar_last_scraped STRING,

    number_of_reviews BIGINT,
    number_of_reviews_ltm BIGINT,
    number_of_reviews_l30d BIGINT,
    availability_eoy BIGINT,
    number_of_reviews_ly BIGINT,

    estimated_occupancy_l365d BIGINT,
    estimated_revenue_l365d DOUBLE,

    first_review TIMESTAMP,
    last_review TIMESTAMP,

    review_scores_rating DOUBLE,
    review_scores_accuracy DOUBLE,
    review_scores_cleanliness DOUBLE,
    review_scores_checkin DOUBLE,
    review_scores_communication DOUBLE,
    review_scores_location DOUBLE,
    review_scores_value DOUBLE,

    instant_bookable STRING,

    calculated_host_listings_count BIGINT,
    calculated_host_listings_count_entire_homes BIGINT,
    calculated_host_listings_count_private_rooms BIGINT,
    calculated_host_listings_count_shared_rooms BIGINT,

    reviews_per_month DOUBLE
)
PARTITIONED BY (
    extraction_date DATE,
    city STRING
)
STORED AS PARQUET
LOCATION '/user/hive/warehouse/airbnb.db/silver/listings';
''')

# 3. Register the partitions (Crucial!)
spark.sql("MSCK REPAIR TABLE airbnb_silver.stg_listings")
# Out:
# DataFrame[]
