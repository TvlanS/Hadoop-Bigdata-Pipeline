# %%
from pyspark.sql import SparkSession
import os 
import pandas as pd

# This forces Pandas to show every single row and column
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)

os.environ['HADOOP_USER_NAME'] = 'root'

spark = SparkSession.builder \
    .appName("bronze-spark-upload-hdfs") \
    .config("spark.driver.host", "spark-notebook") \
    .config("spark.driver.bindAddress", "0.0.0.0") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
df_listings = spark.sql('SELECT * FROM airbnb_bronze.listings')

# %%
# Remove url and metadata columns (such as scraping related information)
df_listings = df_listings.drop('listing_url','host_url','picture_url','scrape_id','last_scraped', 'host_thumbnail_url','host_picture_url')

# %%
# View one row vertically (great for inspection)
df_listings.describe().show(n=1, vertical=True)

# Convert to Pandas for a beautiful interactive table (if in a Notebook)
df_listings.describe().toPandas().transpose()
# Out:
# -RECORD 0----------------------------------------------
#  summary                                      | count
#  id                                           | 110303
#  source                                       | 110303
#  name                                         | 110303
#  description                                  | 107671
#  neighborhood_overview                        | 48258
#  host_id                                      | 110303
#  host_name                                    | 110181
#  host_since                                   | 110183
#  host_location                                | 83881
#  host_about                                   | 57600
#  host_response_time                           | 76724
#  host_response_rate                           | 76724
#  host_acceptance_rate                         | 81304
#  host_is_superhost                            | 108270
#  host_neighbourhood                           | 47714
#  host_listings_count                          | 110183
#  host_total_listings_count                    | 110183
#  host_verifications                           | 110183
#  host_has_profile_pic                         | 110183
#  host_identity_verified                       | 110183
#  neighbourhood                                | 48259
#  neighbourhood_cleansed                       | 110303
#  neighbourhood_group_cleansed                 | 0
#  latitude                                     | 110303
#  longitude                                    | 110303
#  property_type                                | 110303
#  room_type                                    | 110303
#  accommodates                                 | 110303
#  bathrooms                                    | 73650
#  bathrooms_text                               | 110137
#  bedrooms                                     | 96944
#  beds                                         | 73558
#  amenities                                    | 110303
#  price                                        | 73584
#  minimum_nights                               | 110303
#  maximum_nights                               | 110303
#  minimum_minimum_nights                       | 110286
#  maximum_minimum_nights                       | 110286
#  minimum_maximum_nights                       | 110286
#  maximum_maximum_nights                       | 110286
#  minimum_nights_avg_ntm                       | 110303
#  maximum_nights_avg_ntm                       | 110303
#  calendar_updated                             | 0
#  has_availability                             | 105942
#  availability_30                              | 110303
#  availability_60                              | 110303
#  availability_90                              | 110303
#  availability_365                             | 110303
#  calendar_last_scraped                        | 110303
#  number_of_reviews                            | 110303
#  number_of_reviews_ltm                        | 110303
#  number_of_reviews_l30d                       | 110303
#  availability_eoy                             | 110303
#  number_of_reviews_ly                         | 110303
#  estimated_occupancy_l365d                    | 110303
#  estimated_revenue_l365d                      | 73584
#  first_review                                 | 84842
#  last_review                                  | 84842
#  review_scores_rating                         | 84842
#  review_scores_accuracy                       | 84827
#  review_scores_cleanliness                    | 84833
#  review_scores_checkin                        | 84799
#  review_scores_communication                  | 84822
#  review_scores_location                       | 84798
#  review_scores_value                          | 84798
#  license                                      | 110303
#  instant_bookable                             | 110303
#  calculated_host_listings_count               | 110303
#  calculated_host_listings_count_entire_homes  | 110303
#  calculated_host_listings_count_private_rooms | 110303
#  calculated_host_listings_count_shared_rooms  | 110303
#  reviews_per_month                            | 84842
#  city                                         | 110303
# only showing top 1 row
#                                                    0                      1                      2                                                  3                                                  4
# summary                                        count                   mean                 stddev                                                min                                                max
# id                                            110303  6.8811131986286541E17  5.9094187671357299E17                                              13913                                1518113294243873256
# source                                        110303                   None                   None                                        city scrape                                    previous scrape
# name                                          110303                 1956.5      3887.701677512478         ! ! ! Single studio ! ! ! in Golders Green                🤴 Kingsize room with balcony and TV
# description                                   107671      2.203735331717E12  3.1165523939921245E12          Nestled in heart of Islington and only...  🪴 Welcome to our Little Garden Annexe 🪴 <br />...
# neighborhood_overview                          48258  1.111111111111111E123                    0.0  ""Perfect Location for all the christmas festi...  🥂Coal Drops Yard <br />🚂 Kings Cross station <...
# host_id                                       110303    2.121149277162906E8    2.175915788485036E8                                               2381                                          718690455
# host_name                                     110181                    NaN                    NaN                                            'Connor                                                 현주
# host_since                                    110183                   None                   None                                         2008-08-21                                         2025-09-12
# host_location                                  83881                   None                   None                                    A Coruña, Spain                                Šiauliai, Lithuania
# host_about                                     57600               738117.0                   None                                                 \n  안녕하세요. 영국 뉴몰든에 위치한 원룸입니다. 새로 지어서 아주 깨끗하고 런던 여행...
# host_response_time                             76724                   None                   None                                 a few days or more                                     within an hour
# host_response_rate                             76724                   None                   None                                                 0%                                                99%
# host_acceptance_rate                           81304                   None                   None                                                 0%                                                99%
# host_is_superhost                             108270                   None                   None                                                  f                                                  t
# host_neighbourhood                             47714                   None                   None                                         Abbey Wood                                                 火炭
# host_listings_count                           110183      47.04553333998893      375.9319097778665                                                1.0                                             5469.0
# host_total_listings_count                     110183      77.28659593585218      563.8082744054143                                                1.0                                             8774.0
# host_verifications                            110183                   None                   None                 ['email', 'phone', 'photographer']                                                 []
# host_has_profile_pic                          110183                   None                   None                                                  f                                                  t
# host_identity_verified                        110183                   None                   None                                                  f                                                  t
# neighbourhood                                  48259                   None                   None                            Neighborhood highlights                            Neighborhood highlights
# neighbourhood_cleansed                        110303                   None                   None                                          Abbeyhill                                      Windmill Hill
# neighbourhood_group_cleansed                       0                   None                   None                                               None                                               None
# latitude                                      110303      51.70470000944924     0.9201125034401739                                          51.295937                                           55.99195
# longitude                                     110303    -0.4547178211999591     0.8895015204784777                                           -3.44254                                            0.27896
# property_type                                 110303                   None                   None                                               Barn                                               Yurt
# room_type                                     110303                   None                   None                                    Entire home/apt                                        Shared room
# accommodates                                  110303      3.356137185751974      2.109959887281091                                                  1                                                 16
# bathrooms                                      73650     1.3472097759674135     0.7227387561987796                                                0.0                                               26.0
# bathrooms_text                                110137                   None                   None                                            0 baths                                   Shared half-bath
# bedrooms                                       96944     1.6231432579633602     1.0882759628937944                                                0.0                                               50.0
# beds                                           73558     1.9871258054868268     1.5432673736327258                                                0.0                                               50.0
# amenities                                     110303                   None                   None  [" Gilchrist and Soames conditioner", "Safe", ...                                                 []
# price                                          73584                   None                   None                                          $1,000.00                                            $999.00
# minimum_nights                                110303       5.19532560311143     22.706739231081286                                                  1                                               1125
# maximum_nights                                110303      5373.250419299566     1580841.2335397499                                                  1                                          524855552
# minimum_minimum_nights                        110286      4.616333895508043     20.864029992500313                                                1.0                                             1125.0
# maximum_minimum_nights                        110286      8.538572438931505      31.81318608152888                                                1.0                                             1125.0
# minimum_maximum_nights                        110286      5463.523031028417      1580962.799178833                                                1.0                                       5.24855552E8
# maximum_maximum_nights                        110286     258626.94610376656   2.3367532631658647E7                                                1.0                                      2.147483647E9
# minimum_nights_avg_ntm                        110303      5.974142135753319     22.380981826551917                                                1.0                                             1125.0
# maximum_nights_avg_ntm                        110303      256603.3524591348   2.3184436079495348E7                                                1.0                                     2.1357166195E9
# calendar_updated                                   0                   None                   None                                               None                                               None
# has_availability                              105942                   None                   None                                                  t                                                  t
# availability_30                               110303      9.459824302149533     10.929251099460789                                                  0                                                 30
# availability_60                               110303     22.559631197700877     22.904430777219904                                                  0                                                 60
# availability_90                               110303      36.74950817294181      35.33576514071808                                                  0                                                 90
# availability_365                              110303     147.54818091982992     140.72530286183627                                                  0                                                365
# calendar_last_scraped                         110303                   None                   None                                         2025-03-19                                         2025-09-26
# number_of_reviews                             110303      28.12902640907319      66.66653207593181                                                  0                                               1902
# number_of_reviews_ltm                         110303     7.1179931642838365      14.32230382247411                                                  0                                                390
# number_of_reviews_l30d                        110303     0.6309529205914617     1.4806819374884959                                                  0                                                 67
# availability_eoy                              110303      47.05713353217954      48.05810709055767                                                  0                                                288
# number_of_reviews_ly                          110303      6.031368140485753     14.007107077070156                                                  0                                                272
# estimated_occupancy_l365d                     110303     51.251108310744044      78.62978908064204                                                  0                                                255
# estimated_revenue_l365d                        73584      11608.80563709502       74816.4811904697                                                0.0                                            1.015E7
# first_review                                   84842                   None                   None                                         2009-12-21                                         2025-09-23
# last_review                                    84842                   None                   None                                         2011-07-02                                         2025-09-26
# review_scores_rating                           84842      4.696260814219429     0.4770416656123698                                                0.0                                                5.0
# review_scores_accuracy                         84827      4.737673146521829    0.46230154506863663                                                0.0                                                5.0
# review_scores_cleanliness                      84833      4.665596289179929     0.4976711118054236                                                0.0                                                5.0
# review_scores_checkin                          84799      4.798720150001843    0.41315234277962837                                                0.0                                                5.0
# review_scores_communication                    84822     4.8188049091038465    0.41153546414376685                                                0.0                                                5.0
# review_scores_location                         84798      4.736873157385803    0.39476067991431946                                                0.0                                                5.0
# review_scores_value                            84798      4.624590556381102    0.49500301383288287                                                0.0                                                5.0
# license                                       110303                    NaN                    NaN                                        07734317350                                                nan
# instant_bookable                              110303                   None                   None                                                  f                                                  t
# calculated_host_listings_count                110303     16.154220646763914     50.961792644641044                                                  1                                                500
# calculated_host_listings_count_entire_homes   110303     13.920854373861092      50.25392170597605                                                  0                                                499
# calculated_host_listings_count_private_rooms  110303      2.158925867836777      9.064955326663437                                                  0                                                116
# calculated_host_listings_count_shared_rooms   110303   0.026744512841899132      0.601119995749076                                                  0                                                 25
# reviews_per_month                              84842     1.1395376110888698     1.4798330828251152                                               0.01                                              48.55
# city                                          110303                   None                   None                                            bristol                                             london

# %%
# Remove columns with only NULL values

df_listings = df_listings.drop('calendar_updated','neighbourhood_group_cleansed')

# Check distinct values of neighbourhood (only NULL or Neighbourhood highlights)
df_listings.select('neighbourhood').distinct().show()
df_listings = df_listings.drop('neighbourhood')

# Remove columns that does not hold meaningful//analyzable values

df_listings = df_listings.drop('name','description','neighborhood_overview','host_about','license','bathrooms_text','source')
# Out:
# +--------------------+
# |       neighbourhood|
# +--------------------+
# |Neighborhood high...|
# |                NULL|
# +--------------------+

# %%
# some columns has data types that can be formatted

# 1) host_since: string -> datetime
# 2) host_response_time: string -> datetime
# 3） host_response_rate: string -> float
# 4) host_acceptance_rate: string -> float
# 5) price: string -> float
# 6) first_review: string -> datetime
# 7) last_review: string -> datetime

from pyspark.sql.functions import to_timestamp, col, regexp_replace, coalesce, lit, size, current_timestamp

datetime_cols = ['host_since','first_review','last_review']
for c in datetime_cols:
    df_listings = df_listings.withColumn(
        c,
        to_timestamp(c, 'yyyy-MM-dd')
    )

df_listings = df_listings.withColumn(
    'price',
    regexp_replace(col('price'), "[$, ]", "").cast("float")
)

for c in ['host_response_rate','host_acceptance_rate']:
    df_listings = df_listings.withColumn(
        c,
        coalesce(
             regexp_replace(c, "%", "").cast("float") / 100,
            lit(0.0)
        )
    )

# Remove rows where Price is NULL

df_listings = df_listings.filter(
    col('price').isNotNull()
)

# %%
df_listings = df_listings.withColumn('updated_at_utc+0', current_timestamp())

# %%
hdfs_destination = "hdfs://namenode:9000/user/hive/warehouse/airbnb.db/silver/listings"

(df_listings.write
    .mode("overwrite") \
    .partitionBy("extraction_date", "city") \
    .format("parquet") \
    .save(hdfs_destination))

print(f"✅ Ingestion complete. Data stored at: {hdfs_destination}")
# Out:
# ✅ Ingestion complete. Data stored at: hdfs://namenode:9000/user/hive/warehouse/airbnb.db/silver/listings

# %%
# 1. Create the Database
spark.sql("CREATE DATABASE IF NOT EXISTS airbnb_silver")

# 2. Create the Table
spark.sql('''
CREATE EXTERNAL TABLE IF NOT EXISTS airbnb_silver.stg_listings (
    id BIGINT,

    host_id BIGINT,
    host_name STRING,
    host_since TIMESTAMP,
    host_location STRING,
    host_response_time STRING,
    host_response_rate DOUBLE,
    host_acceptance_rate DOUBLE,
    host_is_superhost STRING,
    host_neighbourhood STRING,
    host_listings_count DOUBLE,
    host_total_listings_count DOUBLE,
    host_verifications STRING,
    host_has_profile_pic STRING,
    host_identity_verified STRING,

    neighbourhood_cleansed STRING,
    latitude DOUBLE,
    longitude DOUBLE,

    property_type STRING,
    room_type STRING,
    accommodates BIGINT,
    bathrooms DOUBLE,
    bedrooms DOUBLE,
    beds DOUBLE,
    amenities STRING,

    price FLOAT,

    minimum_nights BIGINT,
    maximum_nights BIGINT,
    minimum_minimum_nights DOUBLE,
    maximum_minimum_nights DOUBLE,
    minimum_maximum_nights DOUBLE,
    maximum_maximum_nights DOUBLE,
    minimum_nights_avg_ntm DOUBLE,
    maximum_nights_avg_ntm DOUBLE,

    has_availability STRING,
    availability_30 BIGINT,
    availability_60 BIGINT,
    availability_90 BIGINT,
    availability_365 BIGINT,

    calendar_last_scraped STRING,

    number_of_reviews BIGINT,
    number_of_reviews_ltm BIGINT,
    number_of_reviews_l30d BIGINT,
    availability_eoy BIGINT,
    number_of_reviews_ly BIGINT,

    estimated_occupancy_l365d BIGINT,
    estimated_revenue_l365d DOUBLE,

    first_review TIMESTAMP,
    last_review TIMESTAMP,

    review_scores_rating DOUBLE,
    review_scores_accuracy DOUBLE,
    review_scores_cleanliness DOUBLE,
    review_scores_checkin DOUBLE,
    review_scores_communication DOUBLE,
    review_scores_location DOUBLE,
    review_scores_value DOUBLE,

    instant_bookable STRING,

    calculated_host_listings_count BIGINT,
    calculated_host_listings_count_entire_homes BIGINT,
    calculated_host_listings_count_private_rooms BIGINT,
    calculated_host_listings_count_shared_rooms BIGINT,

    reviews_per_month DOUBLE
)
PARTITIONED BY (
    extraction_date DATE,
    city STRING
)
STORED AS PARQUET
LOCATION '/user/hive/warehouse/airbnb.db/silver/listings';
''')

# 3. Register the partitions (Crucial!)
spark.sql("MSCK REPAIR TABLE airbnb_silver.stg_listings")
# Out:
# DataFrame[]
